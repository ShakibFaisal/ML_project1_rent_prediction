# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("Dhaka Rent.csv")
df.head()
# Out:
#    area   rent
# 0  2000  31500
# 1  2100  35000
# 2  2500  41050
# 3  2250  36100
# 4  3000  52100

# %%
df.shape
# Out:
# (60, 2)

# %%
df.isnull().sum()
# Out:
# area    0
# rent    0
# dtype: int64

# %%
plt.scatter(df.area,df.rent)
plt.xlabel("area")
plt.ylabel("rent")
plt.title("Rent of Dhaka")
# Out:
# Text(0.5, 1.0, 'Rent of Dhaka')

# %%
x=df[["area"]]
y=df[["rent"]]
y.head()
# Out:
#     rent
# 0  31500
# 1  35000
# 2  41050
# 3  36100
# 4  52100

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.20,random_state=1)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(xtrain,ytrain)
# Out:
# LinearRegression()

# %%
lr.score(xtrain,ytrain)
# Out:
# 0.9536039513606293

# %%
lr.predict()
